# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\Chapman\Data Analyst Project Folder\Web Scraping Project with Disney Movies Dataset\Web Scraping Project(Disney Movies'Dataset).csv")

# %%
df.head()
# Out:
#    Unnamed: 0                            Title  \
# 0           0  Snow White and the Seven Dwarfs
# 1           1                        Pinocchio
# 2           2                         Fantasia
# 3           3             The Reluctant Dragon
# 4           4                            Dumbo
#
#                                          Directed by  \
# 0  ['David Hand', 'William Cottrell', 'Wilfred Ja...
# 1  ['Ben Sharpsteen', 'Hamilton Luske', 'Bill Rob...
# 2  ['Samuel Armstrong', 'James Algar', 'Bill Robe...
# 3  ['Alfred Werker', '(live action)', 'Hamilton L...
# 4  ['Ben Sharpsteen', 'Norman Ferguson', 'Wilfred...
#
#                                           Written by  \
# 0  ['Ted Sears', 'Richard Creedon', 'Otto England...
# 1                                                NaN
# 2                                                NaN
# 3  ['Live-action:', 'Ted Sears', 'Al Perkins', 'L...
# 4                                                NaN
#
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                0
# Title                     2
# Directed by               4
# Written by              310
# Based on                234
# Produced by              13
# Starring                 40
# Music by                  9
# Production company      313
# Distributed by            2
# Release dates           336
# Running time             16
# Country                  60
# Language                 25
# Budget                  201
# Box office              122
# Running Time Fixed       16
# Budget_Fixed            207
# Box office_Fixed        130
# Release time fmt        197
# imdb                     25
# metascore               191
# rotten_tomatoes         141
# Story by                345
# Narrated by             460
# Cinematography          126
# Release date            192
# Edited by                47
# Languages               500
# Screenplay by           261
# Countries               469
# Color process           516
# Production companies    213
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 523 entries, 0 to 522
# Data columns (total 47 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            523 non-null    int64
#  1   Title                 521 non-null    object
#  2   Directed by           519 non-null    object
#  3   Written by            213 non-null    object
#  4   Based on              289 non-null    object
#  5   Produced by           510 non-null    object
#  6   Starring              483 non-null    object
#  7   Music by              514 non-null    object
#  8   Production company    210 non-null    object
#  9   Distributed by        521 non-null    object
#  10  Release dates         187 non-null    object
#  11  Running time          507 non-null    object
#  12  Country               463 non-null    object
#  13  Language              498 non-null    object
#  14  Budget                322 non-null    object
# ...

# %% [markdown]
# ## What are the top 30 Disny Movies with Highest Rotten Tomatoes Score ?

# %%
rotten = df.dropna(axis=0, subset=['rotten_tomatoes','Title'])
rotten1=rotten[['Title','rotten_tomatoes']]
rotten1['rotten_tomatoes']=rotten1['rotten_tomatoes'].str.rstrip("%").astype(int)
rotten2=rotten1.sort_values(by=['rotten_tomatoes'],ascending=False).head(30)
rotten2
# Out:
# C:\Users\Chapman\AppData\Local\Temp\ipykernel_38048\795512974.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rotten1['rotten_tomatoes']=rotten1['rotten_tomatoes'].str.rstrip("%").astype(int)
#                                         Title  rotten_tomatoes
# 1                                   Pinocchio              100
# 357         Tinker Bell and the Lost Treasure              100
# 35                                 Old Yeller              100
# 53                           Greyfriars Bobby              100
# 25   Davy Crockett: King of the Wild Frontier              100
# 491                                 Pinocchio              100
# 41         Darby O'Gill and the Little People              100
# ...

# %%
plt.figure(figsize=(18,9))
plt.title('Top 30 Disny Movies with Highest Rotten Tomatoes Score ', size = 20)
sns.barplot(data=rotten2, y='Title', x ='rotten_tomatoes',linewidth = 2,palette='viridis')
plt.ylabel("Movie's Title", size=10)
plt.xlabel('Rating',size=10)
plt.show()

# %% [markdown]
# ## What are the top 30 Disny Movies with Lowest IMDB Score ?

# %%
imdb = df.dropna(axis=0, subset=['imdb','Title'])
imdb=imdb[['Title','imdb']]
imdb['imdb']=imdb['imdb'].astype(int)
imdb2=imdb.sort_values(by=['imdb'],ascending=False).tail(30)
imdb2
# Out:
#                                                  Title  imdb
# 245                                     102 Dalmatians     4
# 232                                   Doug's 1st Movie     4
# 386                                   Treasure Buddies     4
# 260                                  The Country Bears     4
# 227                    The Jungle Book: Mowgli's Story     4
# 215                                      That Darn Cat     4
# 384                                     Spooky Buddies     4
# 203                       A Kid in King Arthur's Court     4
# 342                 High School Musical 3: Senior Year     4
# 330                                           Underdog     4
# 343                                     Roadside Romeo     4
# 178                           Honey, I Blew Up the Kid     4
# 464                                       Artemis Fowl     4
# 322              The Santa Clause 3: The Escape Clause     4
# ...

# %%
plt.figure(figsize=(10,5))
plt.title('Top 30 Disny Movies with Lowest IMDB Score ', size = 20)
sns.barplot(data=imdb2, y='Title', x ='imdb',linewidth = 2)
plt.ylabel("Movie's Title", size=10)
plt.xlabel('Rating',size=10)
plt.show()

# %% [markdown]
# ## Top 5 Disney Movies with the Highest Budget

# %%
Budget_Fixed = df.dropna(axis=0, subset=['Budget_Fixed','Title'])
Budget_Fixed =Budget_Fixed [['Title','Budget_Fixed']]
Budget_Fixed['Budget_Fixed']=Budget_Fixed['Budget_Fixed'].astype(int)
Budget_Fixed2=Budget_Fixed.sort_values(by=['Budget_Fixed'],ascending=False).head(5)
Budget_Fixed2
# Out:
#                                            Title  Budget_Fixed
# 381  Pirates of the Caribbean: On Stranger Tides     410600000
# 388                                  John Carter     306600000
# 327     Pirates of the Caribbean: At World's End     300000000
# 372                                      Tangled     260000000
# 337     The Chronicles of Narnia: Prince Caspian     225000000

# %%
plt.figure(figsize=(20,9))
plt.title('Top 5 Budgets for Disny Movies', size = 20)
sns.barplot(data=Budget_Fixed2, y='Budget_Fixed', x ='Title',linewidth = 2)
plt.xlabel("Movie's Title", size=10)
plt.ylabel('Budget',size=10)
plt.show()

print(' The highest budget would be 410.6 million for Pirates of the Caribbean: On Stranger Tides !')
# Out:
#  The highest budget would be 410.6 million for Pirates of the Caribbean: On Stranger Tides !

# %% [markdown]
# ## Correlation between Budget and Rotten Tomatoes score

# %%
corr = df.dropna(axis=0, subset=['Budget_Fixed','Title','rotten_tomatoes'])
corr =corr [['Title','Budget_Fixed','rotten_tomatoes']]
corr['Budget_Fixed']=corr['Budget_Fixed'].astype(int)
corr['rotten_tomatoes']=corr['rotten_tomatoes'].str.rstrip("%").astype(int)
corr
# Out:
#                       Title  Budget_Fixed  rotten_tomatoes
# 1                 Pinocchio       2600000              100
# 2                  Fantasia       2280000               95
# 3      The Reluctant Dragon        600000              100
# 4                     Dumbo        950000               98
# 5                     Bambi        858000               91
# ..                      ...           ...              ...
# 515              Robin Hood       5000000               43
# 516               SpaceCamp      18000000               46
# 518          The Aristocats       4000000               63
# 519  The Sword in the Stone       3000000               66
# 521           The Rocketeer      35000000               66
#
# [286 rows x 3 columns]

# %%
plt.figure(figsize=(15,6))
sns.regplot(data=corr, x='Budget_Fixed',y='rotten_tomatoes',scatter_kws={'color':'blue'},line_kws={'color':'red'})
plt.title('Budget vs Ratings', size=17)
plt.show()

print("Budget & Rotten Tomatoes's Ratings has no correlation of each other since the correlation is 0.08 which is nearly 0")
# Out:
# Budget & Rotten Tomatoes's Ratings has no correlation of each other since the correlation is 0.08 which is nearly 0

# %%
corr.corr()
# Out:
#                  Budget_Fixed  rotten_tomatoes
# Budget_Fixed         1.000000         0.089643
# rotten_tomatoes      0.089643         1.000000
